# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadmustakim-sketch/pemograman-dasar-/blob/main/Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya

nama_lengkap   = "Muhammad Mustakim"
nama_panggilan = "mustakim"
jenis_kelamin  = "laki laki"
agama          = "islam"
hobi           = "sepak bola"
tempat_lahir   = "batam"
umur           = 20
tanggal_lahir  = 9
bulan_lahir    = 12
tahun_lahir    = 2005
jurusan        = "RPE"
semester       = 3
matakuliah     = "pemerograman dasar"
status_lulus   = False
Github         = "https://github.com/muhammadmustakim-sketch"
NIM            = 4232511049

print (nama_lengkap)
print (nama_panggilan)
print (jenis_kelamin)
print (agama)
print (hobi)
print (tempat_lahir)
print (umur)
print (tanggal_lahir)
print (bulan_lahir)
print (tahun_lahir)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (Github)
print (NIM)
# Out:
# Muhammad Mustakim
# mustakim
# laki laki
# islam
# sepak bola
# batam
# 20
# 9
# 12
# 2005
# RPE
# 3
# pemerograman dasar
# False
# https://github.com/muhammadmustakim-sketch
# 4232511049
