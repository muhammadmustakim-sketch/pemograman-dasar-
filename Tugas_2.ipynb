# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadmustakim-sketch/pemograman-dasar-/blob/main/Tugas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tugas Pertemuan 2

 # Jawaban Latihan 1

volt = 18
ampere = 6
jenis_sel = "Monocrystalline"

print(volt)
print(ampere)
print(jenis_sel)

 # Jawaban Latihan 2

jumlah_resistor = 10
nilai_resistor = 220.5
aktif = True
nama_komponen = "Resistor"

print

# Jawaban Latihan 3

Nama_unit = "PLTS_Nunukan"
jumlah_panel =240
tegangan_keluaran=48,5
Sedang_beroperasi=True

print(type(Nama_unit))
print(type(jumlah_panel))
print(type(tegangan_keluaran))
print(type(Sedang_beroperasi))


# Jawaban Latihan 4

tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# (a) Cetak pembacaan pertama dan terakhir memakai indeks
print("Pembacaan pertama:", tegangan_harian[0])
print("Pembacaan terakhir:", tegangan_harian[-1])

# (b) Tambahkan satu pembacaan baru 222.0
tegangan_harian.append(222.0)

# (c) Cetak jumlah total data dengan len()
print("Jumlah total data:", len(tegangan_harian))

# jawaban latihan 5

# Membuat dictionary spesifikasi motor listrik
motor = {
    "nama": "Motor Induksi 3 Fasa",
    "daya_kW": 7.5,
    "tegangan_V": 380,
    "rpm": 1450
}

# Cetak salah satu nilai menggunakan key
print("RPM awal:", motor["rpm"])

# Mengubah nilai rpm menggunakan operator =
motor["rpm"] = 1500

# Cetak ulang seluruh dictionary
print("Dictionary terbaru:", motor)

# jawaban latihan 6

pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

# 1. Cetak nama unit kedua (indeks ke-1)
print("Nama unit kedua:", pembangkit[1]["nama"])

# 2. Ubah status salah satu unit (contoh: Unit-3 diubah menjadi 'operasi')
pembangkit[2]["status"] = "operasi"

# 3. Tambahkan satu unit baru menggunakan append()
pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 200, "status": "standby"})

# 4. Cetak seluruh data
print("Seluruh data pembangkit:")
for unit in pembangkit:
    print(unit)
# Out:
# 18
# 6
# Monocrystalline
# <class 'str'>
# <class 'int'>
# <class 'tuple'>
# <class 'bool'>
# Pembacaan pertama: 217.5
# Pembacaan terakhir: 216.9
# Jumlah total data: 7
# RPM awal: 1450
# Dictionary terbaru: {'nama': 'Motor Induksi 3 Fasa', 'daya_kW': 7.5, 'tegangan_V': 380, 'rpm': 1500}
# Nama unit kedua: Unit-2
# Seluruh data pembangkit:
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}
# {'nama': 'Unit-4', 'kapasitas_MW': 200, 'status': 'standby'}
